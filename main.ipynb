# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("fintech.csv")
print("Rows, Columns:", df.shape)
df.head()
# Out:
# Rows, Columns: (100800, 19)
#   transaction_id customer_id transaction_date  transaction_amount  \
# 0     TX00000000     C003581       2024-10-15               34.42
# 1     TX00000001     C005809       2024-02-28              169.45
# 2     TX00000002     C010993       2024-08-28              172.59
# 3     TX00000003     C011810       2024-05-15              129.60
# 4     TX00000004     C009897       2024-09-24              239.33
#
#   transaction_type merchant_category country device_type  ip_risk_score  \
# 0          payment           grocery      FR         pos           99.6
# 1         TRANSFER       electronics      NG         atm           13.2
# 2         transfer            crypto      DE      mobile           72.1
# 3         TRANSFER            crypto      DE         web           30.0
# 4          payment         utilities      RU      mobile           52.7
#
#    customer_age  account_age_days  previous_failed_logins  \
# ...
